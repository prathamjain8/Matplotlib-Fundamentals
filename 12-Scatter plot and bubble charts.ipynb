# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
housing_raw = pd.read_csv("D:/STUDIES/Data Visualization/Data/housing_data.csv", 
                          parse_dates=['period_begin', 'period_end'], 
                          dtype={'total_homes_sold':'Int32', 'region_name': 'category'})

housing_raw.head()
# Out:
#           region_name period_begin period_end  total_homes_sold  inventory  \
# 0  Appling County, GA   2020-04-27 2020-07-19              <NA>        1.0
# 1   Tooele County, UT   2018-08-27 2018-11-18               325        NaN
# 2  Johnson County, TX   2019-09-23 2019-12-15               577      717.0
# 3   Holmes County, OH   2017-10-09 2017-12-31                22       52.0
# 4  Madison County, FL   2017-01-09 2017-04-02                12       54.0
#
#    active_listings  age_of_inventory  median_active_list_price  \
# 0              1.0             222.7                  136195.8
# 1              NaN               NaN                       NaN
# 2            778.0              63.0                  268737.6
# 3             54.0             109.4                  115308.3
# 4             55.0             151.2                  158062.5
#
#    months_of_supply
# 0               NaN
# 1               NaN
# 2         17.095583
# 3         34.050000
# 4         38.300000

# %%
ca_housing = (housing_raw.loc[housing_raw['region_name'].str.contains("CA")]\
.assign(region_name = housing_raw['region_name'].str[0:-11]))

ca_housing.head()
# Out:
#     region_name period_begin period_end  total_homes_sold  inventory  \
# 6    Sacramento   2020-06-22 2020-09-13              5107     1729.0
# 164      Nevada   2018-09-03 2018-11-25               529      480.0
# 252  Stanislaus   2017-06-05 2017-08-27              1572     1042.0
# 293      Tehama   2020-01-20 2020-04-12               102      241.0
# 304  Stanislaus   2017-11-13 2018-02-04              1200      797.0
#
#      active_listings  age_of_inventory  median_active_list_price  \
# 6             2206.0              27.5                  445540.9
# 164            517.0              71.4                  557508.3
# 252           1193.0              38.8                  320660.0
# 293            252.0              99.2                  297979.1
# 304            907.0              56.5                  330049.9
#
#      months_of_supply
# 6            5.235794
# 164         12.165607
# 252          9.212632
# 293         31.530228
# 304          9.744362

# %%
la_housing = ca_housing[ca_housing["region_name"] == "Los Angeles"].sort_index()

# %%
la_housing.head()
# Out:
#       region_name period_begin period_end  total_homes_sold  inventory  \
# 889   Los Angeles   2018-08-20 2018-11-11             16015    20026.0
# 3773  Los Angeles   2017-12-25 2018-03-18             13596    13817.0
# 5859  Los Angeles   2019-01-21 2019-04-14             13372    18580.0
# 6659  Los Angeles   2021-01-11 2021-04-04             16826    12843.0
# 6930  Los Angeles   2018-06-11 2018-09-02             18662    18795.0
#
#       active_listings  age_of_inventory  median_active_list_price  \
# 889           21675.0              51.9                  694662.5
# 3773          15251.0              51.3                  664516.6
# 5859          20097.0              58.2                  697324.3
# 6659          14557.0              44.8                  885070.2
# 6930          20562.0              44.7                  698266.6
#
#       months_of_supply
# 889          16.528985
# 3773         13.834214
# 5859         18.764906
# 6659         10.588778
# ...

# %%
fig, ax = plt.subplots()

ax.scatter(
    la_housing["months_of_supply"],
    la_housing["median_active_list_price"]
)

ax.set_title("Price vs supply in LA")
ax.set_xlabel("Months Of Supply")
ax.set_ylabel("Median List Price")
# Out:
# Text(0, 0.5, 'Median List Price')

# %%
fig, ax = plt.subplots()

ax.scatter(
    la_housing["months_of_supply"],
    la_housing["median_active_list_price"],
    s = (la_housing["median_active_list_price"]*500),
    alpha=.3
)

ax.set_title("Price vs supply in LA")
ax.set_xlabel("Months Of Supply")
ax.set_ylabel("Median List Price")
# Out:
# Text(0, 0.5, 'Median List Price')
