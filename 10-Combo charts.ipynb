# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
housing_raw = pd.read_csv("D:/STUDIES/Data Visualization/Data/housing_data.csv", 
                          parse_dates=['period_begin', 'period_end'], 
                          dtype={'total_homes_sold':'Int32', 'region_name': 'category'})

housing_raw.head()
# Out:
#           region_name period_begin period_end  total_homes_sold  inventory  \
# 0  Appling County, GA   2020-04-27 2020-07-19              <NA>        1.0
# 1   Tooele County, UT   2018-08-27 2018-11-18               325        NaN
# 2  Johnson County, TX   2019-09-23 2019-12-15               577      717.0
# 3   Holmes County, OH   2017-10-09 2017-12-31                22       52.0
# 4  Madison County, FL   2017-01-09 2017-04-02                12       54.0
#
#    active_listings  age_of_inventory  median_active_list_price  \
# 0              1.0             222.7                  136195.8
# 1              NaN               NaN                       NaN
# 2            778.0              63.0                  268737.6
# 3             54.0             109.4                  115308.3
# 4             55.0             151.2                  158062.5
#
#    months_of_supply
# 0               NaN
# 1               NaN
# 2         17.095583
# 3         34.050000
# 4         38.300000

# %%
ca_housing = (housing_raw.loc[(housing_raw["region_name"].str.contains("CA"))]\
                .assign(region_name = housing_raw["region_name"].str[0:-11])\
                .set_index("period_begin"))

# %%
ca_housing.head()
# Out:
#              region_name period_end  total_homes_sold  inventory  \
# period_begin
# 2020-06-22    Sacramento 2020-09-13              5107     1729.0
# 2018-09-03        Nevada 2018-11-25               529      480.0
# 2017-06-05    Stanislaus 2017-08-27              1572     1042.0
# 2020-01-20        Tehama 2020-04-12               102      241.0
# 2017-11-13    Stanislaus 2018-02-04              1200      797.0
#
#               active_listings  age_of_inventory  median_active_list_price  \
# period_begin
# 2020-06-22             2206.0              27.5                  445540.9
# 2018-09-03              517.0              71.4                  557508.3
# 2017-06-05             1193.0              38.8                  320660.0
# 2020-01-20              252.0              99.2                  297979.1
# 2017-11-13              907.0              56.5                  330049.9
#
#               months_of_supply
# period_begin
# 2020-06-22            5.235794
# ...

# %%
sd_dual = (
    ca_housing.loc[ca_housing["region_name"] == "San Diego", ["inventory", "median_active_list_price"]]).sort_index()
sd_dual.head()
# Out:
#               inventory  median_active_list_price
# period_begin
# 2017-01-02       5468.0                  618570.8
# 2017-01-09       5493.0                  621737.5
# 2017-01-16       5520.0                  625820.8
# 2017-01-23       5546.0                  629491.6
# 2017-01-30       5581.0                  632824.0

# %%
fig, ax = plt.subplots()

width = 5

ax.plot(
    sd_dual.index,
    sd_dual["median_active_list_price"],
    color="green",
    alpha = .4,
    label = "Price"
)
ax.legend()

ax2 = ax.twinx()

ax2.bar(
    sd_dual.index,
    sd_dual["inventory"],
    width = width,
    alpha = .3,
    label = "Inventory"
    )

ax2.legend()
fig.legend()

# %%
sd_dual2 = sd_dual.resample("Y").mean()

sd_dual2
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17248\2108416439.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   sd_dual2 = sd_dual.resample("Y").mean()
#                 inventory  median_active_list_price
# period_begin
# 2017-12-31    5986.730769             645314.217308
# 2018-12-31    7438.433962             658434.637736
# 2019-12-31    6794.538462             685614.486538
# 2020-12-31    4494.076923             735517.426923
# 2021-12-31    2975.961538             803811.036538
# 2022-12-31    2692.470588             889710.241176

# %%
fig, ax = plt.subplots()

width = 200

ax.plot(
    sd_dual2["median_active_list_price"],
    color="green",
    alpha = .4,
#     label = "Price"
)
ax.legend()

ax2 = ax.twinx()

ax2.bar(
    sd_dual2.index,
    sd_dual2["inventory"],
    width = width,
    alpha = .3,
    label = "Inventory"
    )

ax2.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
